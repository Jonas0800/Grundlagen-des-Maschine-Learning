# %% [markdown]
# Tom Mitchells "Machine Learning" widmet den Neuronalen Netzen das komplette Kapitel 4-
#
# Bearbeiten Sie Aufgabe 4.1
# Vergleichen Sie die drei praktischen Beispiele in "Machine Learning" (Face Recognition") und "Artificial Intelligence -- A Modern Approach" (Zahlenerkennung und Wortbedeutungen/Immobilienpreise).
# Was fällt Ihnen bei diesen Beispielen auf?
# Welches finden Sie am Anschaulichsten? Warum?
# Wählen Sie ein Beispiel und versuchen Sie es nachzustellen. Was beobachten SIe?

# %% [markdown]
# 4.1. What are the values of weights w0, w1, and w2 for the perceptron whose decision surface is illustrated in Figure 4.3? Assume the surface crosses the x1 axis at -1, and the x2 axis at 2.

# %% [markdown]
# ![image.png](attachment:image.png)
