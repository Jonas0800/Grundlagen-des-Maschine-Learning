# %% [markdown]
# # Tom Mitchells "Machine Learning" widmet den Neuronalen Netzen das komplette Kapitel 4- Bearbeiten Sie Aufgabe 4.1
#
# *What are the values of weights wo, wl, and w2 for the perceptron whose decision
# surface is illustrated in Figure 4.3? Assume the surface crosses the xl axis at -1,
# and the x2 axis at 2.* (Mitchell 2013, S. 124)

# %% [markdown]
# ![image.png](attachment:image.png)
